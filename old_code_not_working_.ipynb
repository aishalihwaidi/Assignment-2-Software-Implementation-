# %% [markdown]
# <a href="https://colab.research.google.com/github/aishalihwaidi/Assignment-2-Software-Implementation-/blob/main/old_code_not_working_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from enum import Enum

class DentalCompany:
    def __init__(self, name,owner,establishmentYear):
        self._name = name
        self._owner = owner
        self._establishmentYear = establishmentYear
        self._branches = []

    def set_name(self, name):
        self._name = name    
    def get_name(self):
        return self._name
    def set_owner(self, owner):
        self._owner = owner
    def get_owner(self):
        return self._owner
    def set_establishment_year(self, establishmentYear):
        self._establishmentYear = establishmentYear
    def get_establishment_year(self):
        return self._establishmentYear    
    def add_branch(self, branch):
        self._branches.append(branch)


class Branch:
    def __init__(self, name, city, contactNumber):
        self._name = name
        self._city = city
        self._contactNumber = contactNumber
        
        self._staff = []
        self._patients = []
        self._services = []

  
    def set_name(self, name):
        self._name = name
    def get_name(self):
        return self._name
    def set_city(self, city):
        self._city = city
    def get_city(self):
        return self._city
    def set_contact_number(self, contactNumber):
        self._contactNumber = contactNumber
    def get_contact_number(self):
        return self._contactNumber  

    def add_staff(self, Staff):
        self._staff.append(Staff)

    def add_patient(self, Patient):
        self._patients.append(Patient)

    def add_service(self, Service):
        self._services.append(Service)




class Service:
    def __init__(self, name, description, price):
        self._name = name
        self._description = description
        self._price = price

    def set_name(self, name):
        self._name = name
    def get_name(self):
        return self._name
    def set_description(self, description):
        self._description = description
    def get_description(self):
        return self._description
    def set_price(self, price):
        self._price = price
    def get_price(self):
        return self._price



class Person:
    def __init__(self, firstName, lastName, gender, dateOfBirth, email):
        self._firstName = firstName
        self._lastName = lastName
        self._gender = gender
        self._dateOfBirth = dateOfBirth
        self._email = email
    
    def set_firstName(self, firstName):
        self._firstName = firstName
    def get_first_name(self):
        return self._firstName
    def set_lastName(self, lastName):
        self._lastName = lastName
    def get_lastName(self):
        return self._lastName
    def set_gender(self, gender):
        self._gender = gender     
    def get_gender(self):
        return self._gender
    def set_dateOfBirth(self, dateOfBirth):
        self._dateOfBirth = dateOfBirth   
    def get_dateOfBirth(self):
        return self._dateOfBirth
    def set_email(self, email):
        self._email = email    
    def get_email(self):
        return self._email



class InsuranceStatus(Enum):
    INSURED = 'insured'
    NOT_INSURED = 'not insured'

class Patient(Person):
    def __init__(self, firstName, lastName, gender, dateOfBirth, email, phoneNumber, insuranceStatus):
        super().__init__(firstName, lastName, gender, dateOfBirth, email)
        self._phoneNumber = phoneNumber
        self._insuranceStatus = insuranceStatus
        self._appointments = []

    def set_phoneNumber(self, phoneNumber):
        self._phoneNumber = phoneNumber 
    def get_phoneNumber(self):
        return self._phoneNumber
    def set_insuranceStatus(self, insuranceStatus):
        self._insuranceStatus = insuranceStatus
    def get_insuranceStatus(self):
        return self._insuranceStatus  

    def add_appointment(self, appointment):
        self._appointments.append(appointment)      

    def get_total_cost(self):
            total_cost = 0
            for appointment in self._appointments:
                total_cost += appointment.get_total_cost()
            return total_cost

    
class Role(Enum):
    MANAGER = "Manager"
    RECEPTIONIST = "Receptionist"
    HYGIENIST = "Hygienist"
    DENTIST = "Dentist"

class Staff(Person):
  def __init__(self, firstName, lastName, gender, dateOfBirth, email, employeeID, role):
    super().__init__(firstName, lastName, gender, dateOfBirth, email)
    self._employeeID = employeeID
    self._role = role

  def set_employeeID(self, employeeID):
    self._employeeID = employeeID    
  def get_employeeID(self):
    return self._employeeID
  def set_role(self, role):
    self._role = role    
  def get_role(self):
    return self._role


class Status(Enum):
  confirmed = "confirmed"
  cancelled = "cancelled"
  completed = "completed"

class Appointment:
  def __init__(self, date, time, patients, staff, services, status):
    self._date = date
    self._time = time

    self._patients = patients
    self._staff = staff
    self._services = services

    self._status = status

  def set_date(self, date):
    self._date = date
  def get_date(self):
    return self._date
    
  def set_time(self, time):
    self._time = time
  def get_time(self):
    return self._time

  def get_serviceDetails(self):
    return [(service._name, service._price) for service in self._services]
  def get_totalPrice(self):
    return sum(service._price() for service in self._services)
  def get_total_cost(self):
        total_cost = 0
        for service in self._services:
            total_cost += service.get_total_cost(service.quantity)
        return total_cost

  def set_status(self, status):
    self._status = status
  def get_status(self):
    return self._status


class PaymentMethod(Enum):
  cash = "cash"
  credit_card = "credit_card"
  debit_card = "debit_card"
  insurance = "insurance"
  installment = "installment"

class Bill:
    def __init__(self, patient, appointments, discount_percentage, payment_method):
        self._patient = patient
        self._appointments = appointments
        self._discount_percentage = discount_percentage
        self._payment_method = payment_method
        self._total_cost = self.calculate_total_cost()
        
    def calculate_total_cost(self):
        total_cost = 0
        for appointment in self.appointments:
            total_cost += appointment.service.cost
        return total_cost * (1 - self.discount_percentage / 100)
    
    def display_bill(self):
        print(f"Patient Name: {self._patient.first_name} {self._patient.last_name}")
        print("Appointments:")
        for appointment in self.appointments:
            print(f"  - {appointment.service.name}: {appointment.service.cost:.2f} AED")
        print(f"Total cost: {self.calculate_total_cost():.2f} AED")

# %%
#Create dental company
dental_company = DentalCompany("Smiles For Life","Aisha Lihwaidi",2003)

#Create a branch and add it to the dental company
a = Branch("Dubai Main Branch", "Dubai", "0501234567")
dental_company.add_branch(a)

#Create services
servicel = Service("Cleaning", 'teeth of patients get cleaned', 100.50)
service2 = Service("Filling",'cavities of patients are filled', 250.90)

  # Add services to the branch (composition relationship)
a.add_service(servicel)
a.add_service(service2)

  # Create staff members (binary association relationship)
manager = Staff("Fatima", "Al Ali", "Female", "12-12-2001","fatime@gmail.com","ED1234",Role.MANAGER) 
dentist = Staff("Ahmed", "Al Mansoori", "Male", "12-12-2001","ahmed@gmail.com","ED1234",Role.DENTIST)

  # Add staff members to the branch (composition relationship)
a.add_staff(manager)
a.add_staff(dentist)

  # Create patients
patient1 = Patient("Khalia", "Al Suwaidi", "055445829", "Male","12-12-2001","ks@gmail.com", InsuranceStatus.INSURED)
patient2 = Patient("Mariam", "Al Hashimi", "059299991", "Female","12-12-2001","mh@gmail.com" ,InsuranceStatus.NOT_INSURED)

# Create an appointment object
appointment1 = Appointment("2023-05-01", "14:30", patient1, dentist, servicel, Status.completed)

# Create a bill for patient1 with the appointment information
bill = Bill([patient1], [appointment1], 13, PaymentMethod.cash)

# Display the bill
bill.display_bill()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-13-642741d4a98a> in <cell line: 32>()
#      30
#      31 # Create a bill for patient1 with the appointment information
# ---> 32 bill = Bill([patient1], [appointment1], 13, PaymentMethod.cash)
#      33
#      34 # Display the bill
#
# <ipython-input-11-b1267564817b> in __init__(self, patient, appointments, discount_percentage, payment_method)
#     219         self._discount_percentage = discount_percentage
#     220         self._payment_method = payment_method
# --> 221         self._total_cost = self.calculate_total_cost()
#     222
#     223     def calculate_total_cost(self):
#
# <ipython-input-11-b1267564817b> in calculate_total_cost(self)
#     223     def calculate_total_cost(self):
#     224         total_cost = 0
# --> 225         for appointment in self.appointments:
# ...

# %%
  def display_bill(self):
      total_cost = 0
      for appointment in self._appointments:
          if appointment.get_status() != "completed":
              print("Service status is not completed. Cannot display receipt.")
              
          else:
              total_cost += appointment.get_totalPrice()
              print(appointment.get_service().get_name(), ":", appointment.get_price(), "AED")
              for patient in self._patients:
                print("Name:", patient.get_firstName(), patient.get_lastName())
              print("Total cost:", total_cost, "AED")

  def display_bill(self):
      total_cost = 0
      for appointment in self._appointments:
        total_cost += appointment.get_totalPrice()
        print(appointment.get_service().get_name(), ":", appointment.get_price(), "AED")
        for patient in self._patients:
          print("Name:", patient.get_firstName(), patient.get_lastName())
        print("Total cost:", total_cost, "AED")             



 return sum(service.get_price for service in self._services)
