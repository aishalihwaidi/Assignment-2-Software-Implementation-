# %% [markdown]
# <a href="https://colab.research.google.com/github/aishalihwaidi/Assignment-2-Software-Implementation-/blob/main/dental_2_working%20code%20but%20still.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from enum import Enum

class DentalCompany:
    def __init__(self, name,owner,establishmentYear):
        self._name = name
        self._owner = owner
        self._establishmentYear = establishmentYear
        self._branches = []

    def set_name(self, name):
        self._name = name    
    def get_name(self):
        return self._name
    def set_owner(self, owner):
        self._owner = owner
    def get_owner(self):
        return self._owner
    def set_establishment_year(self, establishmentYear):
        self._establishmentYear = establishmentYear
    def get_establishment_year(self):
        return self._establishmentYear    
    def add_branch(self, branch):
        self._branches.append(branch)


class Branch:
    def __init__(self, name, city, contactNumber):
        self._name = name
        self._city = city
        self._contactNumber = contactNumber
        
        self._staff = []
        self._patients = []
        self._services = []

  
    def set_name(self, name):
        self._name = name
    def get_name(self):
        return self._name
    def set_city(self, city):
        self._city = city
    def get_city(self):
        return self._city
    def set_contact_number(self, contactNumber):
        self._contactNumber = contactNumber
    def get_contact_number(self):
        return self._contactNumber  

    def add_staff(self, Staff):
        self._staff.append(Staff)

    def add_patient(self, Patient):
        self._patients.append(Patient)

    def add_service(self, Service):
        self._services.append(Service)


class Service:
    def __init__(self, name, description, price):
        self._name = name
        self._description = description
        self._price = price

    def set_name(self, name):
        self._name = name
    def get_name(self):
        return self._name
    def set_description(self, description):
        self._description = description
    def get_description(self):
        return self._description
    def set_price(self, price):
        self._price = price
    def get_price(self):
        return self._price

class Person:
    def __init__(self, firstName, lastName, gender, dateOfBirth, email):
        self._firstName = firstName
        self._lastName = lastName
        self._gender = gender
        self._dateOfBirth = dateOfBirth
        self._email = email
    
    def set_firstName(self, firstName):
        self._firstName = firstName
    def get_firstName(self):
        return self._firstName
    def set_lastName(self, lastName):
        self._lastName = lastName
    def get_lastName(self):
        return self._lastName
    def set_gender(self, gender):
        self._gender = gender     
    def get_gender(self):
        return self._gender
    def set_dateOfBirth(self, dateOfBirth):
        self._dateOfBirth = dateOfBirth   
    def get_dateOfBirth(self):
        return self._dateOfBirth
    def set_email(self, email):
        self._email = email    
    def get_email(self):
        return self._email


class InsuranceStatus(Enum):
    INSURED = 'insured'
    NOT_INSURED = 'not insured'

class Patient(Person):
    def __init__(self, firstName, lastName, gender, dateOfBirth, email, phoneNumber, insuranceStatus):
        super().__init__(firstName, lastName, gender, dateOfBirth, email)
        self._phoneNumber = phoneNumber
        self._insuranceStatus = insuranceStatus
        self._appointments = []

    def set_phoneNumber(self, phoneNumber):
        self._phoneNumber = phoneNumber 
    def get_phoneNumber(self):
        return self._phoneNumber
    def set_insuranceStatus(self, insuranceStatus):
        self._insuranceStatus = insuranceStatus
    def get_insuranceStatus(self):
        return self._insuranceStatus  

    def add_appointment(self, appointment):
        self._appointments.append(appointment)

    
class Role(Enum):
    MANAGER = "Manager"
    RECEPTIONIST = "Receptionist"
    HYGIENIST = "Hygienist"
    DENTIST = "Dentist"

class Staff(Person):
  def __init__(self, firstName, lastName, gender, dateOfBirth, email, employeeID, role):
    super().__init__(firstName, lastName, gender, dateOfBirth, email)
    self._employeeID = employeeID
    self._role = role

  def set_employeeID(self, employeeID):
    self._employeeID = employeeID    
  def get_employeeID(self):
    return self._employeeID
  def set_role(self, role):
    self._role = role    
  def get_role(self):
    return self._role


class Status(Enum):
  confirmed = "confirmed"
  cancelled = "cancelled"
  completed = "completed"

class Appointment:
  def __init__(self, date, time, patients, staff, services, status):
    self._date = date
    self._time = time

    self._patients = patients
    self._staff = staff
    self._services = services

    self._status = status

  def set_date(self, date):
    self._date = date
  def get_date(self):
    return self._date
    
  def set_time(self, time):
    self._time = time
  def get_time(self):
    return self._time

  def get_serviceDetails(self):
    return [(service._name, service._price) for service in self._services]
  def get_totalPrice(self):
   # return sum(service.get_price for service in self._services)
    return sum(service[1] for service in self._services)

  def set_status(self, status):
    self._status = status
  def get_status(self):
    return self._status


class PaymentMethod(Enum):
  cash = "cash"
  credit_card = "credit_card"
  debit_card = "debit_card"
  insurance = "insurance"
  installment = "installment"

class Bill:
  def __init__(self, patients, appointments, services, discounts, paymentMethod):
    self._patients = patients
    self._appointments = appointments
    self._services = services
    self._discounts = discounts
    self._paymentMethod = paymentMethod

  def get_totalCost(self):
    return sum(appointment.get_price for appointment in self._appointments)

  def set_discounts(self, discounts):
    self._discounts = discounts
  def get_discounts(self):
    return self._discounts

  def set_paymentMethod(self, paymentMethod):
    self._paymentMethod = paymentMethod
  def get_paymentMethod(self):
    return self._paymentMethod
  

          
  def display_bill(self):
    total_cost = sum([service.get_price() for service in self._services])
    discount_amount = self._discounts * total_cost
    final_cost = total_cost - discount_amount
    print("---------- Bill ----------")
    #print(f"Date: {self._appointment.get_date()}")
    #print(f"Time: {self._appointment.get_time()}")
    print("Services:")
    for service in self._services:
      print(f"- {service.get_name()}: ${service.get_price()}")
    print(f"Total Cost: ${total_cost}")
    print(f"Discount ({self._discounts * 100}%): ${discount_amount}")
    print(f"Final Cost: ${final_cost}")

# %%
#Create dental company
dental_company = DentalCompany("Smiles For Life","Aisha Lihwaidi",2003)

#Create a branch and add it to the dental company
a = Branch("Dubai Main Branch", "Dubai", "0501234567")
dental_company.add_branch(a)

#Create services
servicel = Service("Cleaning", 'teeth of patients get cleaned', 100.50)
service2 = Service("Filling",'cavities of patients are filled', 250.90)

  # Add services to the branch (composition relationship)
a.add_service(servicel)
a.add_service(service2)

  # Create staff members (binary association relationship)
manager = Staff("Fatima", "Al Ali", "Female", "12-12-2001","fatime@gmail.com","ED1234",Role.MANAGER) 
dentist = Staff("Ahmed", "Al Mansoori", "Male", "12-12-2001","ahmed@gmail.com","ED1234",Role.DENTIST)

  # Add staff members to the branch (composition relationship)
a.add_staff(manager)
a.add_staff(dentist)

  # Create patients
patient1 = Patient("Khalifa", "Al Jarwan", "055445829", "Male","12-12-2001","ks@gmail.com", InsuranceStatus.INSURED)
patient2 = Patient("Mariam", "Al Hashimi", "059299991", "Female","12-12-2001","mh@gmail.com" ,InsuranceStatus.NOT_INSURED)

# Create an appointment object
appointment1 = Appointment("2023-05-01", "14:30", patient1, dentist, servicel, Status.confirmed)

# Create a bill for patient1 with the appointment information
bill = Bill([patient1], [appointment1], [servicel,service2], 0.05, PaymentMethod.cash)

# Display the bill
bill.display_bill()
# Out:
# ---------- Bill ----------
# Services:
# - Cleaning: $100.5
# - Filling: $250.9
# Total Cost: $351.4
# Discount (5.0%): $17.57
# Final Cost: $333.83
